# %%
import pandas as pd
import os

# %%
file_names = [f'train_FD00{num}.txt' for num in range(1, 5)]
file_paths = [os.path.join('..', 'data', 'raw', file_name) for file_name in file_names]

# %%
for path in file_paths:
    try:
        with open(path, 'r') as file:
            lines = [line.strip() for line in file]
        with open(path, 'w') as file:
            file.write('\n'.join(lines))

        index_cols = ['unit number', 'cycle time']
        setting_cols = [f'operational setting {num}' for num in range(1, 4)]
        sensor_cols = [f'sensor measurement {num}' for num in range(1, 22)]
        column_names = index_cols + setting_cols + sensor_cols
        
        df = pd.read_csv(path, sep=' ', header=None, names=column_names, index_col=False, skipinitialspace=True)
        df.dropna(axis=1, how='all', inplace=True)
        
        print(df.iloc[0, :])
        
        print('--- Engine Statistics ---')
        print(f'Current engine: {path}')
        print(f'Max cycle length: {df['cycle time'].max()}')
        print(f'Min cycle length: {df['cycle time'].min()}')

        cycle_lengths = []
        current_unit = -1
        current_cycle_start = 0

        for idx, row in df.iterrows():
            unit_num = row['unit number']
            cycle_time = row['cycle time']

            if unit_num != current_unit:
                if current_unit != -1:
                    cycle_lengths.append(df.iloc[current_cycle_start:idx]['cycle time'].max())
                current_unit = unit_num
                current_cycle_start = idx

        cycle_lengths.append(df.iloc[current_cycle_start:]['cycle time'].max())

        if cycle_lengths:
            average_cycle_length = sum(cycle_lengths) / len(cycle_lengths)
            print(f'Average cycle length: {average_cycle_length}')
        else:
            print('Average cycle length: No cycles found')

    except FileNotFoundError:
        print(f"Error: Training file not found at {path}")
        print("Please ensure the data is placed correctly in the data/raw directory.")
    except Exception as e:
        print(f"An error occurred: {e}")
# Out:
# unit number                 1.0000
# cycle time                  1.0000
# operational setting 1      -0.0007
# operational setting 2      -0.0004
# operational setting 3     100.0000
# sensor measurement 1      518.6700
# sensor measurement 2      641.8200
# sensor measurement 3     1589.7000
# sensor measurement 4     1400.6000
# sensor measurement 5       14.6200
# sensor measurement 6       21.6100
# sensor measurement 7      554.3600
# sensor measurement 8     2388.0600
# sensor measurement 9     9046.1900
# sensor measurement 10       1.3000
# sensor measurement 11      47.4700
# sensor measurement 12     521.6600
# sensor measurement 13    2388.0200
# sensor measurement 14    8138.6200
# sensor measurement 15       8.4195
# sensor measurement 16       0.0300
# sensor measurement 17     392.0000
# sensor measurement 18    2388.0000
# sensor measurement 19     100.0000
# sensor measurement 20      39.0600
# sensor measurement 21      23.4190
# Name: 0, dtype: float64
# --- Engine Statistics ---
# Current engine: ../data/raw/train_FD001.txt
# Max cycle length: 362
# Min cycle length: 1
# Average cycle length: 206.31
# unit number                 1.0000
# cycle time                  1.0000
# operational setting 1      34.9983
# operational setting 2       0.8400
# operational setting 3     100.0000
# sensor measurement 1      449.4400
# sensor measurement 2      555.3200
# sensor measurement 3     1358.6100
# sensor measurement 4     1137.2300
# sensor measurement 5        5.4800
# sensor measurement 6        8.0000
# sensor measurement 7      194.6400
# sensor measurement 8     2222.6500
# sensor measurement 9     8341.9100
# sensor measurement 10       1.0200
# sensor measurement 11      42.0200
# sensor measurement 12     183.0600
# sensor measurement 13    2387.7200
# sensor measurement 14    8048.5600
# sensor measurement 15       9.3461
# sensor measurement 16       0.0200
# sensor measurement 17     334.0000
# sensor measurement 18    2223.0000
# sensor measurement 19     100.0000
# sensor measurement 20      14.7300
# sensor measurement 21       8.8071
# Name: 0, dtype: float64
# --- Engine Statistics ---
# Current engine: ../data/raw/train_FD002.txt
# Max cycle length: 378
# Min cycle length: 1
# Average cycle length: 206.76538461538462
# unit number                 1.0000
# cycle time                  1.0000
# operational setting 1      -0.0005
# operational setting 2       0.0004
# operational setting 3     100.0000
# sensor measurement 1      518.6700
# sensor measurement 2      642.3600
# sensor measurement 3     1583.2300
# sensor measurement 4     1396.8400
# sensor measurement 5       14.6200
# sensor measurement 6       21.6100
# sensor measurement 7      553.9700
# sensor measurement 8     2387.9600
# sensor measurement 9     9062.1700
# sensor measurement 10       1.3000
# sensor measurement 11      47.3000
# sensor measurement 12     522.3100
# sensor measurement 13    2388.0100
# sensor measurement 14    8145.3200
# sensor measurement 15       8.4246
# sensor measurement 16       0.0300
# sensor measurement 17     391.0000
# sensor measurement 18    2388.0000
# sensor measurement 19     100.0000
# sensor measurement 20      39.1100
# sensor measurement 21      23.3537
# Name: 0, dtype: float64
# --- Engine Statistics ---
# Current engine: ../data/raw/train_FD003.txt
# Max cycle length: 525
# Min cycle length: 1
# Average cycle length: 247.2
# unit number                 1.0000
# cycle time                  1.0000
# operational setting 1      42.0049
# operational setting 2       0.8400
# operational setting 3     100.0000
# sensor measurement 1      445.0000
# sensor measurement 2      549.6800
# sensor measurement 3     1343.4300
# sensor measurement 4     1112.9300
# sensor measurement 5        3.9100
# sensor measurement 6        5.7000
# sensor measurement 7      137.3600
# sensor measurement 8     2211.8600
# sensor measurement 9     8311.3200
# sensor measurement 10       1.0100
# sensor measurement 11      41.6900
# sensor measurement 12     129.7800
# sensor measurement 13    2387.9900
# sensor measurement 14    8074.8300
# sensor measurement 15       9.3335
# sensor measurement 16       0.0200
# sensor measurement 17     330.0000
# sensor measurement 18    2212.0000
# sensor measurement 19     100.0000
# sensor measurement 20      10.6200
# sensor measurement 21       6.3670
# Name: 0, dtype: float64
# --- Engine Statistics ---
# Current engine: ../data/raw/train_FD004.txt
# Max cycle length: 543
# Min cycle length: 1
# Average cycle length: 245.97991967871485

# %%
df = pd.DataFrame({'Name': ['Alice', 'Bob', 'Aritra'],
                   'Age': [25, 30, 35],
                   'Location': ['Seattle', 'New York', 'Kona']},
                  index=([10, 20, 30]))

df[df.index == 10]
# Out:
#      Name  Age Location
# 10  Alice   25  Seattle
